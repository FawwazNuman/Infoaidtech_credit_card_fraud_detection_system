# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.pandas.set_option("display.max_columns",None)
credit = pd.read_csv("creditcard.csv")
credit
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# ...

# %%
credit.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
credit.duplicated(keep = 'first').sum()
# Out:
# 1081

# %%
credit.drop_duplicates(keep = 'first',inplace=True)
credit.duplicated().sum()
# Out:
# 0

# %%
credit.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %% [markdown]
# This is higly unbalansed data_frame

# %%
legit = credit[credit.Class == 0]
fraud = credit[credit.Class == 1]
fraud.shape
# Out:
# (473, 31)

# %% [markdown]
# we take legit also 473 because we have fraud 473

# %%
legit_sample = legit.sample(n = 473)

# %%
new_df = pd.concat([legit_sample,fraud],axis=0)
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92305.934461  0.162573 -0.051484  0.075497 -0.038574 -0.020569
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9       V10       V11       V12  \
# Class
# 0      0.106885 -0.094526 -0.094414  0.067454  0.035175  0.045696  0.088881
# 1     -1.432518 -5.175912  0.953255 -2.522124 -5.453274  3.716347 -6.103254
#
#             V13       V14       V15       V16       V17       V18       V19  \
# Class
# 0      0.071490 -0.107356 -0.010274  0.022710  0.012213  0.005447  0.017501
# 1     -0.094324 -6.835946 -0.072830 -4.000956 -6.463285 -2.157071  0.669143
#
#             V20      V21       V22       V23       V24       V25       V26  \
# Class
# 0     -0.035071  0.01540  0.038247 -0.021515 -0.007512  0.026677  0.024654
# 1      0.405043  0.46655  0.086639 -0.096464 -0.106643  0.040615  0.050456
#
# ...

# %% [markdown]
# Splitting dependent and independent variable

# %%
x = new_df.drop(columns="Class",axis= 1)
y = new_df["Class"]

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test = train_test_split  (x,y,test_size = 0.2, stratify = y ,random_state = 2)

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_train_prediction = model.predict(x_train)
accuarcy = accuracy_score(x_train_prediction,y_train)
print("Accuarcy score : ",accuarcy)
# Out:
# Accuarcy score :  0.9272486772486772

# %%
test_data = model.predict(x_test)
test_data_ytest = accuracy_score(test_data,y_test)
print("Test Accuracy: ",test_data_ytest)
# Out:
# Test Accuracy:  0.9263157894736842
